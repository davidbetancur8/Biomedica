# %% [markdown]
# # NLP
#
# <img src="https://cdn.searchenginejournal.com/wp-content/uploads/2020/08/an-introduction-to-natural-language-processing-with-python-for-seos-5f3519eeb8368.png">

# %% [markdown]
# Las computadoras y las máquinas son excelentes para trabajar con datos tabulares u hojas de cálculo. Sin embargo, como los seres humanos generalmente se comunican en palabras y oraciones, no en forma de tablas. Mucha de la información que los humanos hablan o escriben no está estructurada. Por tanto, no está muy claro que las computadoras lo interpreten. En el procesamiento del lenguaje natural (PNL), el objetivo es hacer que las computadoras comprendan el texto no estructurado y recuperen información significativa de él. El procesamiento del lenguaje natural (PNL) es un subcampo de la inteligencia artificial, en el que su profundidad involucra las interacciones entre computadoras y humanos.

# %% [markdown]
# ## Applications of NLP:
# * Machine Translation.
# * Speech Recognition.
# * Sentiment Analysis.
# * Question Answering.
# * Summarization of Text.
# * Chatbot.
# * Intelligent Systems.
# * Text Classifications.
# * Character Recognition.
# * Spell Checking.
# * Spam Detection.
# * Autocomplete.
# * Named Entity Recognition.
# * Predictive Typing.

# %% [markdown]
# ## NLTK

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Tokenize

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
example_string = """
Muad'Dib learned rapidly because his first training was in how to learn.
And the first lesson of all was the basic trust that he could learn.
It's shocking to find how many people do not believe they can learn,
and how many more believe learning to be difficult."""

# %%
sent_tokenize(example_string)
# Out:
# ["\nMuad'Dib learned rapidly because his first training was in how to learn.",
#  'And the first lesson of all was the basic trust that he could learn.',
#  "It's shocking to find how many people do not believe they can learn,\nand how many more believe learning to be difficult."]

# %%
word_tokenize(example_string)
# Out:
# ["Muad'Dib",
#  'learned',
#  'rapidly',
#  'because',
#  'his',
#  'first',
#  'training',
#  'was',
#  'in',
#  'how',
#  'to',
#  'learn',
#  '.',
#  'And',
#  'the',
#  'first',
#  'lesson',
#  'of',
#  'all',
#  'was',
#  'the',
#  'basic',
#  'trust',
#  'that',
#  'he',
#  'could',
#  'learn',
#  '.',
#  'It',
#  "'s",
#  'shocking',
#  'to',
#  'find',
#  'how',
#  'many',
#  'people',
#  'do',
#  'not',
#  'believe',
#  'they',
#  'can',
#  'learn',
#  ',',
#  'and',
#  'how',
#  'many',
#  'more',
#  'believe',
#  'learning',
#  'to',
#  'be',
#  'difficult',
#  '.']

# %% [markdown]
# ## Stopwords

# %%
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
stop_words = set(stopwords.words("english"))
list(stop_words)[:10]
# Out:
# ['hasn',
#  'isn',
#  'herself',
#  'yourselves',
#  'your',
#  "you'd",
#  'other',
#  'nor',
#  'between',
#  "needn't"]

# %%
worf_quote = "Sir, I protest. I am not a merry man!"

# %%
words_in_quote = word_tokenize(worf_quote)
words_in_quote
# Out:
# ['Sir', ',', 'I', 'protest', '.', 'I', 'am', 'not', 'a', 'merry', 'man', '!']

# %%
filtered_list = [w for w in words_in_quote if w.lower() not in stop_words]
filtered_list
# Out:
# ['Sir', ',', 'protest', '.', 'merry', 'man', '!']

# %% [markdown]
# ## Stemming
#
# Consiste en reducir la palabra a su raíz. Por ejemplo  “helping” y “helper” comparten la raíz “help.”

# %%
from nltk.stem import PorterStemmer
from nltk.tokenize import word_tokenize

# %%
stemmer = PorterStemmer()

# %%
string_for_stemming = """
The crew of the USS Discovery discovered many discoveries.
Discovering is what explorers do."""

# %%
words = word_tokenize(string_for_stemming)

# %%
stemmed_words = [stemmer.stem(word) for word in words]

# %%
for w, s in zip(words, stemmed_words):
  print(w, s)
# Out:
# The the
# crew crew
# of of
# the the
# USS uss
# Discovery discoveri
# discovered discov
# many mani
# discoveries discoveri
# . .
# Discovering discov
# is is
# what what
# explorers explor
# do do
# . .

# %% [markdown]
# **Understemming**: happens when two related words should be reduced to the same stem but aren’t. This is a false negative.
#
# **Overstemming**: happens when two unrelated words are reduced to the same stem even though they shouldn’t be. This is a false positive.

# %% [markdown]
# ## Tagging PoS
#
# | Part of speech | Role                                                                       | Examples                   |
# |----------------|----------------------------------------------------------------------------|----------------------------|
# | Noun           | Is a person, place, or thing                                               | mountain, bagel, Poland    |
# | Pronoun        | Replaces a noun                                                            | you, she, we               |
# | Adjective      | Gives information about what a noun is like                                | efficient, windy, colorful |
# | Verb           | Is an action or a state of being                                           | learn, is, go              |
# | Adverb         | Gives information about a verb, an adjective, or another adverb            | efficiently, always, very  |
# | Preposition    | Gives information about how a noun or pronoun is connected to another word | from, about, at            |
# | Conjunction    | Connects two other words or phrases                                        | so, because, and           |
# | Interjection   | Is an exclamation                                                          | yay, ow, wow               |

# %%
from nltk.tokenize import word_tokenize

# %%
sagan_quote = """
If you wish to make an apple pie from scratch,
you must first invent the universe."""

# %%
words_in_sagan_quote = word_tokenize(sagan_quote)

# %%
import nltk
nltk.download('averaged_perceptron_tagger')
nltk.download('tagsets')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package tagsets to /root/nltk_data...
# [nltk_data]   Unzipping help/tagsets.zip.
# True

# %%
nltk.pos_tag(words_in_sagan_quote)
# Out:
# [('If', 'IN'),
#  ('you', 'PRP'),
#  ('wish', 'VBP'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('an', 'DT'),
#  ('apple', 'NN'),
#  ('pie', 'NN'),
#  ('from', 'IN'),
#  ('scratch', 'NN'),
#  (',', ','),
#  ('you', 'PRP'),
#  ('must', 'MD'),
#  ('first', 'VB'),
#  ('invent', 'VB'),
#  ('the', 'DT'),
#  ('universe', 'NN'),
#  ('.', '.')]

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
# ...

# %% [markdown]
# # Lemmatizing
#
# reduces words to their core meaning, but it will give you a complete English word that makes sense on its own instead of just a fragment of a word

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
lemmatizer = WordNetLemmatizer()

# %%
lemmatizer.lemmatize("scarves")
# Out:
# 'scarf'

# %% [markdown]
# # Spacy
#
# https://spacy.io

# %%
import spacy

# Load English tokenizer, tagger, parser and NER
nlp = spacy.load("en_core_web_sm")

# Process whole documents
text = ("When Sebastian Thrun started working on self-driving cars at "
        "Google in 2007, few people outside of the company took him "
        "seriously. “I can tell you very senior CEOs of major American "
        "car companies would shake my hand and turn away because I wasn’t "
        "worth talking to,” said Thrun, in an interview with Recode earlier "
        "this week.")
doc = nlp(text)

# Analyze syntax
print("Noun phrases:", [chunk.text for chunk in doc.noun_chunks])
print("Verbs:", [token.lemma_ for token in doc if token.pos_ == "VERB"])

# Find named entities, phrases and concepts
for entity in doc.ents:
    print(entity.text, entity.label_)

# %% [markdown]
# # Nubes de palabras
#
# https://www.kaggle.com/zynicide/wine-reviews/data

# %%
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt
% matplotlib inline

# %%
df = pd.read_csv("winemag-data-130k-v2.csv", index_col=0)
df.head()
# Out:
#     country  ...               winery
# 0     Italy  ...              Nicosia
# 1  Portugal  ...  Quinta dos Avidagos
# 2        US  ...            Rainstorm
# 3        US  ...           St. Julian
# 4        US  ...         Sweet Cheeks
#
# [5 rows x 13 columns]

# %%
df[["country", "description","points"]].head()
# Out:
#     country                                        description  points
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87
# 2        US  Tart and snappy, the flavors of lime flesh and...      87
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87
# 4        US  Much like the regular bottling from 2012, this...      87

# %%
country = df.groupby("country")

# Summary statistic of all countries
country.describe().head()
# Out:
#                         points                       ... price
#                          count       mean       std  ...   50%    75%     max
# country                                              ...
# Argentina               3800.0  86.710263  3.179627  ...  17.0  25.00   230.0
# Armenia                    2.0  87.500000  0.707107  ...  14.5  14.75    15.0
# Australia               2329.0  88.580507  2.989900  ...  21.0  38.00   850.0
# Austria                 3345.0  90.101345  2.499799  ...  25.0  36.50  1100.0
# Bosnia and Herzegovina     2.0  86.500000  2.121320  ...  12.5  12.75    13.0
#
# [5 rows x 16 columns]

# %%
country.mean().sort_values(by="points",ascending=False).head()
# Out:
#             points      price
# country
# England  91.581081  51.681159
# India    90.222222  13.333333
# Austria  90.101345  30.762772
# Germany  89.851732  42.257547
# Canada   89.369650  35.712598

# %%
# ?WordCloud

# %%
# Start with one review:
text = df.description[0]
text
# Out:
# "Aromas include tropical fruit, broom, brimstone and dried herb. The palate isn't overly expressive, offering unripened apple, citrus and dried sage alongside brisk acidity."

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# lower max_font_size, change the maximum number of word and lighten the background:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
text = " ".join(review for review in df.description)
print ("There are {} words in the combination of all review.".format(len(text)))
# Out:
# There are 31661073 words in the combination of all review.

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["drink", "now", "wine", "flavor", "flavors"])

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
# the matplotlib way:
plt.figure(figsize=(10,10))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# # Ejercicio
#
# Usar la siguiente tabla para hacaer un análisis exploratorio de los twits de algunos de los politicos en Colombia.
#
# **Pistas**:
#
# * para stopwords en español: https://pypi.org/project/stop-words/

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/davidbetancur8/Biomedica/master/ds_2021/03-modelacion/datos/tweet_politicos.csv")

# %%
df
# Out:
#                  name                                              tweet
# 0      AlvaroUribeVel  Grave atentado en Neiva contra el periodista W...
# 1      AlvaroUribeVel  Álvaro Uribe advierte a Madrid, 'faro de la Hi...
# 2      AlvaroUribeVel  Vándalo-terrorismo destruye peaje de Gachancip...
# 3      AlvaroUribeVel  Comunidad informa:  “En Puerto Rellena, Cali, ...
# 4      AlvaroUribeVel  Comerciantes de Pereira defienden sus locales;...
# ...               ...                                                ...
# 25395  sergio_fajardo  "Yo seré el presidente de la reconciliación, y...
# 25396  sergio_fajardo  Llegamos a Neiva. Siempre me alegra. #sepuede....
# 25397  sergio_fajardo  Desde hoy #ElEquipo trinará bajo ese hashtag y...
# 25398  sergio_fajardo  Si en esta cuenta está mi equipo de trabajo (#...
# 25399  sergio_fajardo  ¿Cuántas personas caben en una cuenta de Twitt...
#
# [25400 rows x 2 columns]
